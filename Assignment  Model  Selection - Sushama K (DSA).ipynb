# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(r"C:\Users\susha\Downloads\titanic_dataset.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Age'] = data['Age'].fillna(data['Age'].median())

# %%
data['Cabin'] = data['Cabin'].fillna(data['Cabin'].mode())

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode())

# %%
data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250       G6        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
data = data.drop(['Cabin','Name',"Ticket"],axis=1)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
#Outlier detection

# %%
num_cols=["SibSp",'Age', 'Parch',"Survived",'Pclass','Fare']
for i in num_cols:
    plt.figure()
    plt.boxplot(data[i])
    plt.title(i)

# %%
Q1 = np.percentile(data['Age'],25,interpolation='midpoint')
Q2 = np.percentile(data['Age'],50,interpolation='midpoint')
Q3 = np.percentile(data['Age'],75,interpolation='midpoint')
print(Q1,Q2,Q3)
# Out:
# 22.0 28.0 35.0
# C:\Users\susha\AppData\Local\Temp\ipykernel_21012\2750967288.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data['Age'],25,interpolation='midpoint')
# C:\Users\susha\AppData\Local\Temp\ipykernel_21012\2750967288.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(data['Age'],50,interpolation='midpoint')
# C:\Users\susha\AppData\Local\Temp\ipykernel_21012\2750967288.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
Q1 = data['Age'].quantile(0.25)
Q3 = data['Age'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 +(whisker_width*IQR)
data['Age']=np.where(data['Age']>upper_whisker,upper_whisker,np.where(data['Age']<lower_whisker,lower_whisker,data['Age']))

# %%
Q1 = data['Fare'].quantile(0.25)
Q3 = data['Fare'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 +(whisker_width*IQR)
data['Fare']=np.where(data['Fare']>upper_whisker,upper_whisker,np.where(data['Fare']<lower_whisker,lower_whisker,data['Fare']))

# %%
Q1 = data['Parch'].quantile(0.25)
Q3 = data['Parch'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 +(whisker_width*IQR)
data['Parch']=np.where(data['Parch']>upper_whisker,upper_whisker,np.where(data['Parch']<lower_whisker,lower_whisker,data['Parch']))

# %%
Q1 = data['SibSp'].quantile(0.25)
Q3 = data['SibSp'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 +(whisker_width*IQR)
data['SibSp']=np.where(data['SibSp']>upper_whisker,upper_whisker,np.where(data['SibSp']<lower_whisker,lower_whisker,data['SibSp']))

# %%
num_cols=["SibSp",'Age', 'Parch',"Survived",'Pclass','Fare']
for i in num_cols:
    plt.figure()
    plt.boxplot(data[i])
    plt.title(i)

# %% [markdown]
# # SVM AND KNN MODEL

# %%
#Label encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data["Sex"] = le.fit_transform(data['Sex'])
data['Embarked'] = le.fit_transform(data['Embarked'])

# %%
data["Embarked"].unique()
# Out:
# array([2, 0, 1, 3])

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0    1.0    0.0   7.2500         2
# 1            2         1       1    0  38.0    1.0    0.0  65.6344         0
# 2            3         1       3    0  26.0    0.0    0.0   7.9250         2
# 3            4         1       1    0  35.0    1.0    0.0  53.1000         2
# 4            5         0       3    1  35.0    0.0    0.0   8.0500         2

# %%
X = data.drop('Survived',axis = 1).values
Y = data['Survived']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=42,test_size=0.25)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0    1.0    0.0   7.2500         2
# 1            2         1       1    0  38.0    1.0    0.0  65.6344         0
# 2            3         1       3    0  26.0    0.0    0.0   7.9250         2
# 3            4         1       1    0  35.0    1.0    0.0  53.1000         2
# 4            5         0       3    1  35.0    0.0    0.0   8.0500         2

# %%
#SVM model
from sklearn.svm import SVC
svmclf = SVC(kernel = "linear")
svmclf.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svmclf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
print("Accuracy =" ,accuracy_score(y_test,y_pred))
print("Confusion matrix =" ,confusion_matrix(y_test,y_pred))
# Out:
# Accuracy = 0.7847533632286996
# Confusion matrix = [[112  22]
#  [ 26  63]]

# %%
from sklearn.neighbors import KNeighborsClassifier
metric = []
neighbors = np.arange(3,15)
for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors = k, metric = "minkowski",p=2)
    classifier.fit(x_train,y_train)
    y_pred_knn = classifier.predict(x_test)
    acc = accuracy_score(y_test,y_pred_knn)
    metric.append(acc)

# %%
plt.plot(neighbors,metric, "o-")
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
# The highest accuracy score is for k = 7
classifier = KNeighborsClassifier(n_neighbors = 7, metric = "minkowski",p=2)
classifier.fit(x_train,y_train)
y_pred_knn = classifier.predict(x_test)

# %%
print("Accuracy =" ,accuracy_score(y_test,y_pred_knn))
print("Precision = ", precision_score(y_test,y_pred_knn))
print("Recall = " ,recall_score(y_test,y_pred_knn))
print("f1 Score = " ,f1_score(y_test,y_pred_knn))
# Out:
# Accuracy = 0.6591928251121076
# Precision =  0.6274509803921569
# Recall =  0.3595505617977528
# f1 Score =  0.45714285714285713

# %% [markdown]
# Result = The max accuracy is obtained for SVM model

# %% [markdown]
# # K - fold cross validation

# %%
from sklearn.model_selection import KFold

# %%
kfold_validator = KFold(10)

# %%
for train_index,test_index in kfold_validator.split(X,Y):
    print("Training Index: ",train_index)
    print("Testing Index: ",test_index)
# Out:
# Training Index:  [ 90  91  92  93  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression(fit_intercept=True)
lr= LinearRegression()

# %%
cv_result = cross_val_score(lr_model,X,Y,cv=kfold_validator)

# %%
cv_result
# Out:
# array([0.39321211, 0.15038591, 0.33797815, 0.37510057, 0.37207144,
#        0.39738965, 0.36213718, 0.3165345 , 0.50170909, 0.39545448])

# %%
mean_outcome = np.mean(cv_result)

# %%
 print("Mean Accuracy: {0}".format(mean_outcome))
# Out:
# Mean Accuracy: 0.3833219795977612

# %% [markdown]
# # Straitified Cross validation

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skfold_validator = StratifiedKFold(n_splits=10)

# %%
for train_index,test_index in skfold_validator.split(X,Y):
    print("Training Index: ",train_index)
    print("Testing Index: ",test_index)
# Out:
# Training Index:  [ 82  84  85  88  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
skcv_result = cv_result = cross_val_score(lr_model,X,Y,cv=skfold_validator)

# %%
skcv_result
# Out:
# array([0.39592109, 0.34563054, 0.26080865, 0.42505736, 0.41824487,
#        0.37033691, 0.39730821, 0.35588693, 0.45733826, 0.40668698])

# %%
mean_outcome = np.mean(skcv_result)

# %%
print("Mean Accuracy: {0}".format(mean_outcome))
# Out:
# Mean Accuracy: 0.3833219795977612
